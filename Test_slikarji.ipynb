# %%
# Render our plots inline
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)
# Out:
# \\Spin\RacU$\_System\ApplicationData\Python\Python34\site-packages\matplotlib\__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# \\Spin\RacU$\_System\ApplicationData\Python\Python34\site-packages\matplotlib\__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
slikarji = pd.read_csv('./podatki/katalog/catalog.csv',sep=';',encoding='latin1')

# %%
slikarji[:9]
# Out:
#                    AUTHOR                                          BORN-DIED  \
# 0        AACHEN, Hans von                    (b. 1552, Köln, d. 1615, Praha)
# 1        AACHEN, Hans von                    (b. 1552, Köln, d. 1615, Praha)
# 2        AACHEN, Hans von                    (b. 1552, Köln, d. 1615, Praha)
# 3        AACHEN, Hans von                    (b. 1552, Köln, d. 1615, Praha)
# 4        AACHEN, Hans von                    (b. 1552, Köln, d. 1615, Praha)
# 5  AAGAARD, Carl Frederik              (b. 1833, Odense, d. 1895, K?benhavn)
# 6  AAGAARD, Carl Frederik              (b. 1833, Odense, d. 1895, K?benhavn)
# 7      ABADIA, Juan de la                       (active 1470-1490 in Huesca)
# 8      ABAQUESNE, Masséot  (b. ca 1500, Cherbourg, d. 1564, Sotteville-l?...
#
#                                 TITLE     DATE                    TECHNIQUE  \
# 0                            Allegory     1598    Oil on copper, 56 x 47 cm
# 1            Bacchus, Ceres and Cupid        -  Oil on canvas, 163 x 113 cm
# 2                       Joking Couple        -      Copperplate, 25 x 20 cm
# 3       Portrait of Emperor Rudolf II    1590s    Oil on canvas, 60 x 48 cm
# 4  Self-Portrait with a Glass of Wine  c. 1596    Oil on canvas, 53 x 44 cm
# 5                  Deer beside a Lake     1888    Oil on canvas, 53 x 82 cm
# 6                     The Rose Garden     1877    Oil on canvas, 98 x 80 cm
# 7               The Archangel Michael  c. 1490            Wood, 127 x 78 cm
# 8                           Albarello  c. 1545                     Maiolica
#
#                                        LOCATION  \
# 0                       Alte Pinakothek, Munich
# 1              Kunsthistorisches Museum, Vienna
# 2              Kunsthistorisches Museum, Vienna
# 3              Kunsthistorisches Museum, Vienna
# 4                            Private collection
# 5                            Private collection
# 6                            Private collection
# 7  Museu Nacional d'Art de Catalunya, Barcelona
# 8                   Musée des Beaux-Arts, Rouen
#
#                                                URL      FORM          TYPE  \
# 0    http://www.wga.hu/html/a/aachen/allegory.html  painting  mythological
# 1     http://www.wga.hu/html/a/aachen/bacchus.html  painting  mythological
# 2    http://www.wga.hu/html/a/aachen/j_couple.html  painting         genre
# 3     http://www.wga.hu/html/a/aachen/rudolf2.html  painting      portrait
# 4    http://www.wga.hu/html/a/aachen/selfport.html  painting      portrait
# 5   http://www.wga.hu/html/a/aagaard/deerlake.html  painting     landscape
# 6   http://www.wga.hu/html/a/aagaard/rosegard.html  painting     landscape
# 7     http://www.wga.hu/html/a/abadia/michael.html  painting     religious
# 8  http://www.wga.hu/html/a/abaquesn/albarell.html  ceramics         other
#
#     SCHOOL  TIMEFRAME
# 0   German  1601-1650
# 1   German  1601-1650
# 2   German  1601-1650
# 3   German  1601-1650
# 4   German  1601-1650
# 5   Danish  1851-1900
# 6   Danish  1851-1900
# 7  Spanish  1451-1500
# 8   French  1501-1550
