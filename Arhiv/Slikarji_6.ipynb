# %%
import pandas as pd
from PIL import Image

#Razpredelnice za delo s podatki
slikarji = pd.read_csv('./csv-datoteke/seznam_slikarji.csv',sep=';',encoding='latin1',index_col='Id_slikarja')
slike = pd.read_csv('./csv-datoteke/seznam_slik.csv',sep=';',encoding='latin1',index_col='Id_slike')

#Število izpisov po stolpcih in vrsticah.
pd.options.display.max_rows = 15
pd.options.display.max_columns = 16

# %matplotlib inline

import matplotlib.pyplot as plt
from pandas import DataFrame
from mpl_toolkits.mplot3d import Axes3D

pd.set_option('display.mpl_style', 'default')
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 5)

# %%
slikarji
# Out:
#                                       Ime Narodnost    Obdobje
# Id_slikarja
# 1536                      GALLE, Cornelis   Flemish  1601-1650
# 412                  BLANCHARD, Pharamond    French  1801-1850
# 2607          MASTER of Citt? di Castello   Italian  1301-1350
# 2766                     MEUCCI, Vincenzo   Italian  1701-1750
# 3199         PERRIN, Jean-Charles-Nicaise    French  1751-1800
# 3872                  SLAVÃ?EK, AntonÃ­n  Bohemian  1851-1900
# 3382                  PYNAS, Jan Symonsz.     Dutch  1601-1650
# ...                                   ...       ...        ...
# 1980                 HOUASSE, Michel-Ange    French  1701-1750
# 1851                  HAMEN, Juan van der   Spanish  1601-1650
# 873              CINGANELLI, Michelangelo   Italian  1601-1650
# 3049            OMMEGANCK, Balthazar Paul   Flemish  1751-1800
# 453                     BOLDRINI, Niccol?   Italian  1501-1550
# 3303          POLENOV, Vasily Dmitrievich   Russian  1851-1900
# 4144            TROTTI, Giovanni Battista   Italian  1551-1600
#
# [4611 rows x 3 columns]

# %%
slikarji_po_narodnosti = slikarji.groupby('Narodnost').size()
slikarji_po_narodnosti.plot(color='b',kind='bar')

# %%
slikarji_po_obdobjih = slikarji.groupby('Obdobje').size()
slikarji_po_obdobjih.plot(color='b')

# %%
slikarji_glede_na_obdobje_po_narodnosti=slikarji.groupby(['Obdobje','Narodnost']).size().unstack()
slikarji_glede_na_obdobje_po_narodnosti.plot(kind='bar')

# %%
Narod = 'Hungarian'
Narod_slikarji=slikarji[slikarji.Narodnost==Narod]
stevilo_Narod_slikarjev_v_obdobju=Narod_slikarji.groupby('Obdobje').size()
stevilo_Narod_slikarjev_v_obdobju.plot(color='b')

# %%
Obdobje='1751-1800'
Obdobje_slikarji=slikarji[slikarji.Obdobje==Obdobje]
stevilo_v_Obdobju_slikarjev_glede_na_narodnost=Obdobje_slikarji.groupby('Narodnost').size()
stevilo_v_Obdobju_slikarjev_glede_na_narodnost.plot(color='b',kind='bar')

# %%
slike
# Out:
#           Id_slikarja                                    Naslov  \
# Id_slike
# 24546            2886               Queen Mary Tudor of England
# 27321            3307                      Hercules and Antaeus
# 21464            2622         Madonna and Child with Six Angels
# 34418            4085                     Portrait of a Senator
# 21569            2644  Laudario of the Compagnia di Sant'Agnese
# 4826              619                      View of the interior
# 30303            3577         Apostles James the Great and Paul
# ...               ...                                       ...
# 37494            4353                   The Triumph of Mordecai
# 29906            3529             Ditch at Place de la Concorde
# 24950            2933                     The Condemned Cell II
# 30779            3632                          Virgin and Child
# 13708            1649                Presentation in the Temple
# 17283            1985                             Denis Diderot
# 29674            3508                        Sacrifice of Isaac
#
#                                               Tehnika  \
# Id_slike
# 24546                       Oil on panel, 109 x 84 cm
# 27321                      Tempera on wood, 16 x 9 cm
# 21464                     Tempera on wood, 65 x 43 cm
# 34418                     Oil on canvas, 119 x 100 cm
# 21569     Tempera and gold on parchment, 430 x 317 mm
# 4826                                            Photo
# 30303                                           Stone
# ...                                               ...
# 37494                     Oil on canvas, 500 x 370 cm
# 29906                         Red chalk, 360 x 480 mm
# 24950                   Oil on canvas, 119 x 170,5 cm
# 30779                     Oil on canvas, 151 x 108 cm
# 13708                     Tempera on wood, 44 x 43 cm
# 17283                        Terracotta, height 83 cm
# 29674                      Oil on canvas 149 x 229 cm
#
#                                                    Lokacija        Oblika  \
# Id_slike
# 24546                               Museo del Prado, Madrid      painting
# 27321                       Galleria degli Uffizi, Florence      painting
# 21464               The Morgan Library and Museum, New York      painting
# 34418                      Museo Thyssen-Bornemisza, Madrid      painting
# 21569                                    Private collection  illumination
# 4826              Cappella dei Pazzi, Santa Croce, Florence  architecture
# 30303     Abbey Church of Saint-Gilles, Saint-Gilles-du-...     sculpture
# ...                                                     ...           ...
# 37494                                San Sebastiano, Venice      painting
# 29906                              MusÃ©e Carnavalet, Paris      graphics
# 24950                     Magyar Nemzeti GalÃ©ria, Budapest      painting
# 30779                             Staatliche Museen, Berlin      painting
# 13708               Isabella Stewart Gardner Museum, Boston      painting
# 17283                               MusÃ©e du Louvre, Paris     sculpture
# 29674                Galleria Nazionale d'Arte Antica, Rome      painting
#
#                    Tip
# Id_slike
# 24546         portrait
# 27321     mythological
# 21464        religious
# 34418         portrait
# 21569        religious
# 4826          interior
# 30303        religious
# ...                ...
# 37494     mythological
# 29906        landscape
# 24950            genre
# 30779        religious
# 13708        religious
# 17283         portrait
# 29674        religious
#
# [39302 rows x 6 columns]

# %%
slike_oblika=slike.groupby('Oblika').size().sort_values(ascending=False)
slike_oblika.plot(kind='bar',color='g')

# %%
slike_tip=slike.groupby('Tip').size().sort_values(ascending=False)
slike_tip.plot(kind='bar',color='b')

# %%
oblika_in_njen_tip=slike.groupby(['Oblika','Tip']).size().unstack()
oblika_in_njen_tip.plot(kind='bar')

# %%
najvecje_zbirke_slike_lokacija=slike.groupby('Lokacija').size().sort_values(ascending=False).head(20)
najvecje_zbirke_slike_lokacija.plot(kind='pie')

# %%
zdruzeni_tabeli=slike.join(slikarji, on='Id_slikarja')
zdruzeni_tabeli
# Out:
#           Id_slikarja                                    Naslov  \
# Id_slike
# 24546            2886               Queen Mary Tudor of England
# 27321            3307                      Hercules and Antaeus
# 21464            2622         Madonna and Child with Six Angels
# 34418            4085                     Portrait of a Senator
# 21569            2644  Laudario of the Compagnia di Sant'Agnese
# 4826              619                      View of the interior
# 30303            3577         Apostles James the Great and Paul
# ...               ...                                       ...
# 37494            4353                   The Triumph of Mordecai
# 29906            3529             Ditch at Place de la Concorde
# 24950            2933                     The Condemned Cell II
# 30779            3632                          Virgin and Child
# 13708            1649                Presentation in the Temple
# 17283            1985                             Denis Diderot
# 29674            3508                        Sacrifice of Isaac
#
#                                               Tehnika  \
# Id_slike
# 24546                       Oil on panel, 109 x 84 cm
# 27321                      Tempera on wood, 16 x 9 cm
# 21464                     Tempera on wood, 65 x 43 cm
# 34418                     Oil on canvas, 119 x 100 cm
# 21569     Tempera and gold on parchment, 430 x 317 mm
# 4826                                            Photo
# 30303                                           Stone
# ...                                               ...
# 37494                     Oil on canvas, 500 x 370 cm
# 29906                         Red chalk, 360 x 480 mm
# 24950                   Oil on canvas, 119 x 170,5 cm
# 30779                     Oil on canvas, 151 x 108 cm
# 13708                     Tempera on wood, 44 x 43 cm
# 17283                        Terracotta, height 83 cm
# 29674                      Oil on canvas 149 x 229 cm
#
#                                                    Lokacija        Oblika  \
# Id_slike
# 24546                               Museo del Prado, Madrid      painting
# 27321                       Galleria degli Uffizi, Florence      painting
# 21464               The Morgan Library and Museum, New York      painting
# 34418                      Museo Thyssen-Bornemisza, Madrid      painting
# 21569                                    Private collection  illumination
# 4826              Cappella dei Pazzi, Santa Croce, Florence  architecture
# 30303     Abbey Church of Saint-Gilles, Saint-Gilles-du-...     sculpture
# ...                                                     ...           ...
# 37494                                San Sebastiano, Venice      painting
# 29906                              MusÃ©e Carnavalet, Paris      graphics
# 24950                     Magyar Nemzeti GalÃ©ria, Budapest      painting
# 30779                             Staatliche Museen, Berlin      painting
# 13708               Isabella Stewart Gardner Museum, Boston      painting
# 17283                               MusÃ©e du Louvre, Paris     sculpture
# 29674                Galleria Nazionale d'Arte Antica, Rome      painting
#
#                    Tip                                Ime Narodnost    Obdobje
# Id_slike
# 24546         portrait                  MORA, Bernardo de   Spanish  1651-1700
# 27321     mythological              POLLAIUOLO, Piero del   Italian  1451-1500
# 21464        religious            MASTER of Saint Cecilia   Italian  1301-1350
# 34418         portrait                     TIRALI, Andrea   Italian  1651-1700
# 21569        religious  MASTER of the Dresden Prayer Book   Flemish  1451-1500
# 4826          interior                    BRUNI, Domenico   Italian  1601-1650
# 30303        religious        ROMANESQUE SCULPTOR, German    German  1101-1150
# ...                ...                                ...       ...        ...
# 37494     mythological             VERROCCHIO, Andrea del   Italian  1451-1500
# 29906        landscape                   ROBERT, LÃ©opold     Swiss  1801-1850
# 24950            genre                   MUNRO, Alexander  Scottish  1851-1900
# 30779        religious                    RUBLYOV, Andrey   Russian  1401-1450
# 13708        religious                 GIOVANETTI, Matteo   Italian  1301-1350
# 17283         portrait                     HOYAU, Charles    French  1601-1650
# 29674        religious                  RIMINALDI, Orazio   Italian  1601-1650
#
# [39302 rows x 9 columns]

# %%
stevilo_narisanih_slik_narodnost=zdruzeni_tabeli.groupby('Narodnost')
stevilo_narisanih_slik_narodnost.size().sort_values(ascending=False).plot(kind='bar',color='g')

# %%
stevilo_narisanih_slik_obdobje=zdruzeni_tabeli.groupby('Obdobje')
stevilo_narisanih_slik_obdobje.size().plot(kind='bar',color='y')

# %%
Oblika_glede_na_narodnost=zdruzeni_tabeli.groupby(['Narodnost','Oblika']).size()
Oblika_glede_na_narodnost.unstack().plot(kind='bar')

# %%
Oblika_glede_na_obdobje=zdruzeni_tabeli.groupby(['Obdobje','Oblika']).size()
Oblika_glede_na_obdobje.unstack().plot(kind='bar')

# %%
Tip_glede_na_narodnost=zdruzeni_tabeli.groupby(['Narodnost','Tip']).size()
Tip_glede_na_narodnost.unstack().plot(kind='bar')

# %%
Tip_glede_na_obdobje=zdruzeni_tabeli.groupby(['Obdobje','Tip']).size()
Tip_glede_na_obdobje.unstack().plot(kind='bar')

# %%
najvecje_stevilo_del=zdruzeni_tabeli.groupby('Ime')
najvecje_stevilo_del.size().sort_values(ascending=False).head(20).plot(kind='bar')

# %%
oblika_s_katero_so_se_ukvarjali=zdruzeni_tabeli.groupby(['Id_slikarja','Oblika']).count()
oblike=oblika_s_katero_so_se_ukvarjali.reset_index()[['Id_slikarja','Oblika']]
oblike.groupby('Oblika').size().plot(kind='bar',color='g')

# %%
NaslovS=''
TehnikaS='Oil on canvas'
LokacijaS=''
OblikaS='painting'
TipS='mythological'
NarodnostS1='French'
ObdobjeS1=''

sez1=[NaslovS,TehnikaS,LokacijaS,OblikaS,TipS,NarodnostS1,ObdobjeS1]
sez2=['Naslov','Tehnika','Lokacija','Oblika','Tip','Narodnost','Obdobje']

i=0
filtrirano=zdruzeni_tabeli
while i!=len(sez1):
    if sez1[i]!='':
        filtrirano=filtrirano.reset_index().set_index(sez2[i]).loc[sez1[i]].set_index('Id_slikarja')
    i+=1
zbrano=filtrirano.reset_index()
prikaz=zbrano.drop(['Id_slike','Id_slikarja'],axis=1)
prikaz
# Out:
#                                   Naslov  \
# 0              Erminia and the Shepherds
# 1                              Bathsheba
# 2       Sacred and Profane Love (detail)
# 3   Apollo Guarding the Herds of Admetus
# 4          Minerva in her Study (detail)
# 5                  Venus, Mars and Cupid
# 6              Venus and Adonis (detail)
# ..                                   ...
# 43      Sacred and Profane Love (detail)
# 44                       DanaÃ« (detail)
# 45      Sacred and Profane Love (detail)
# 46   Orpheus and the Bacchantes (detail)
# 47             Venus and Adonis (detail)
# 48     Young Girl at the Scamander River
# 49           The Rape of Europa (detail)
#
#                                              Lokacija  \
# 0                                  Private collection
# 1                             MusÃ©e du Louvre, Paris
# 2                             Galleria Borghese, Rome
# 3                                  Private collection
# 4                     The Leiden Collection, New York
# 5                          Pinacoteca Estense, Modena
# 6                             Museo del Prado, Madrid
# ..                                                ...
# 43                            Galleria Borghese, Rome
# 44                      The Hermitage, St. Petersburg
# 45                            Galleria Borghese, Rome
# 46  Museo del Settecento Veneziano, Ca' Rezzonico,...
# 47                            Museo del Prado, Madrid
# 48  MusÃ©e des Beaux-Arts et de la Dentelle d'Alen...
# 49                        Museum of Art, Philadelphia
#
#                              Ime    Obdobje
# 0               CLAUDEL, Camille  1851-1900
# 1      DROUAIS, FranÃ§ois-Hubert  1701-1750
# 2                 TOCQUÃ, Louis  1701-1750
# 3               CLAUDEL, Camille  1851-1900
# 4   RÃMOND, Jean-Charles-Joseph  1801-1850
# 5           GUÃRIN, Jean-Urbain  1751-1800
# 6                 TOCQUÃ, Louis  1701-1750
# ..                           ...        ...
# 43                TOCQUÃ, Louis  1701-1750
# 44  RÃMOND, Jean-Charles-Joseph  1801-1850
# 45                TOCQUÃ, Louis  1701-1750
# 46              LE BRUN, Charles  1651-1700
# 47                TOCQUÃ, Louis  1701-1750
# 48              COURTEYS, Pierre  1551-1600
# 49             COYSEVOX, Antoine  1651-1700
#
# [50 rows x 4 columns]

# %%
#Vnesi index slike:
j=0

index_slikarja=zbrano.Id_slikarja.iloc[j]
index_slike=zbrano.Id_slike.iloc[j]

img=Image.open('podatki/seznam_slik/'+str(index_slikarja)+'/'+str(index_slike)+'.jpg')
img.show()

# %%
ImeS=''
NarodnostS='Italian'
ObdobjeS=''

sez1s=[ImeS,NarodnostS,ObdobjeS]
sez2s=['Ime','Narodnost','Obdobje']

i=0
filtrirano2=slikarji
while i!=len(sez1s):
    if sez1s[i]!='':
        filtrirano2=filtrirano2.reset_index().set_index(sez2s[i]).loc[sez1s[i]].set_index('Id_slikarja')
    i+=1
zbrano2=filtrirano2
prikaz2=zbrano2.reset_index().drop(['Id_slikarja'],axis=1)
prikaz2
# Out:
#                                     Ime    Obdobje
# 0           MASTER of Citt? di Castello  1301-1350
# 1                      MEUCCI, Vincenzo  1701-1750
# 2     ORIOLI, Pietro di Francesco degli  1451-1500
# 3         FREDIANI, Vincenzo di Antonio  1451-1500
# 4                 GUIDOBONO, Bartolomeo  1651-1700
# 5                               PACECCO  1601-1650
# 6            TIEPOLO, Giovanni Battista  1701-1750
# ...                                 ...        ...
# 1526                  MASTER of Bigallo  1201-1250
# 1527            BARBIERI, Paolo Antonio  1601-1650
# 1528             SAVIN, Paolo di Matteo  1501-1550
# 1529           PIAZZA DA LODI, Callisto  1501-1550
# 1530           CINGANELLI, Michelangelo  1601-1650
# 1531                  BOLDRINI, Niccol?  1501-1550
# 1532          TROTTI, Giovanni Battista  1551-1600
#
# [1533 rows x 2 columns]

# %%
#Vnesi index slikarja:
k=0
najdi_slike_po_tem_indexu=zbrano2.reset_index().Id_slikarja.iloc[k]
najdi_slike_po_tem_indexu

najdeni=slike.join(zbrano2, on='Id_slikarja')
poiskano=najdeni.dropna()
najdene_slike_slikarja=poiskano[poiskano.Id_slikarja==najdi_slike_po_tem_indexu].reset_index()
najdene_slike_slikarja
prikaz3=najdene_slike_slikarja.drop(['Id_slike','Id_slikarja'],axis=1)
prikaz3
# Out:
#                                               Naslov  \
# 0                                  Group of capitals
# 1  Crucifixion with the Virgin and St John the Ev...
# 2                                  Sculptured column
# 3                                          Male Head
# 4                        Christ Walking on the Water
# 5  The Death and Martyrdom of St Saturninus (detail)
# 6             Martyrdom of St Saturninus of Toulouse
#
#                                      Tehnika  \
# 0                                      Stone
# 1  Tempera on panel, gold ground, 39 x 35 cm
# 2                                     Marble
# 3                       Marble, height 31 cm
# 4                   White marble, 82 x 61 cm
# 5                                     Marble
# 6                               White marble
#
#                                         Lokacija     Oblika        Tip  \
# 0    L'Assomption-de-Notre-Dame, Rieux-Minervois  sculpture  religious
# 1                             Private collection   painting  religious
# 2  Museo di Arte Sacra, San Casciano Val di Pesa  sculpture  religious
# 3              Mateu collection, Perelada Castle  sculpture      other
# 4                Museu Frederic Mar?s, Barcelona  sculpture  religious
# 5        Benedictine Abbey, Saint-Hilaire-d'Aude  sculpture  religious
# 6        Benedictine Abbey, Saint-Hilaire-d'Aude  sculpture  religious
#
#                            Ime    Obdobje
# 0  MASTER of Citt? di Castello  1301-1350
# 1  MASTER of Citt? di Castello  1301-1350
# 2  MASTER of Citt? di Castello  1301-1350
# 3  MASTER of Citt? di Castello  1301-1350
# 4  MASTER of Citt? di Castello  1301-1350
# 5  MASTER of Citt? di Castello  1301-1350
# 6  MASTER of Citt? di Castello  1301-1350

# %%
#Vnesi index slike slikarja:
l=0

index_slikarja=najdene_slike_slikarja.Id_slikarja.iloc[l]
index_slike=najdene_slike_slikarja.Id_slike.iloc[l]

img=Image.open('podatki/seznam_slik/'+str(index_slikarja)+'/'+str(index_slike)+'.jpg')
img.show()
